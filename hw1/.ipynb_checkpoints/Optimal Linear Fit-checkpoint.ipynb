# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random as rand
from numpy.linalg import inv
# %matplotlib inline

# %%
X = np.matrix('1 0; 1 2; 1 3; 1 4')
y = np.matrix('1; 3; 6; 8')
theta = inv(X.T.dot(X)).dot(X.T).dot(y) 
print(X.dot(theta))
theta
# Out:
# [[ 0.51428571]
#  [ 4.05714286]
#  [ 5.82857143]
#  [ 7.6       ]]
# matrix([[ 0.51428571],
#         [ 1.77142857]])

# %%
plt.figure()
points = np.matrix('0; 2; 3; 4')
plt.scatter(np.matrix('0; 2; 3; 4'), y)
plt.plot([0,2,3,4], X.dot(theta))
plt.savefig('optimal.png')

# %%
# 100 vaues between 0 and 4
random_x = np.random.random([100]) * 4
val_noise = []
for x in random_x:
    y_val = 0.51428571 + 1.77142857*x
    noise = np.random.normal(loc=0.0, scale=1.0, size=1)
    val_noise += [y_val + noise]
print(val_noise)
colors = np.random.rand(100)
plt.scatter(random_x, val_noise, c= colors)
# Out:
# [array([ 7.16875294]), array([ 4.07192497]), array([ 5.42687463]), array([ 6.29028376]), array([ 4.72461475]), array([ 3.10472115]), array([ 5.98091802]), array([ 6.16445798]), array([ 6.06514593]), array([ 5.80672604]), array([ 6.00838547]), array([ 3.13649376]), array([ 2.84412937]), array([ 6.53528265]), array([ 5.78887306]), array([ 3.6733172]), array([ 2.43303624]), array([ 6.01378208]), array([ 3.65705052]), array([ 5.8780085]), array([ 1.54797245]), array([ 2.50430267]), array([ 2.56811723]), array([ 2.22467569]), array([ 2.61745061]), array([ 5.20368345]), array([ 1.91762283]), array([ 6.50506554]), array([ 1.18403879]), array([ 2.99776766]), array([ 2.25768081]), array([ 3.22242369]), array([ 1.80624459]), array([ 1.91260462]), array([ 8.53920968]), array([ 3.66020273]), array([ 0.60628021]), array([ 6.18947798]), array([ 0.48386676]), array([ 1.23223228]), array([ 4.96309886]), array([ 3.0360633]), array([ 5.13269887]), array([ 6.00609814]), array([ 7.10828199]), array([ 7.29380544]), array([ 6.45857021]), array([ 4.61256031]), array([ 5.15861147]), array([ 3.83344391]), array([ 1.10003234]), array([ 3.74991145]), array([-0.66445777]), array([ 0.70662777]), array([ 6.77403989]), array([ 5.37941015]), array([ 8.34848563]), array([ 1.85516441]), array([ 4.15407095]), array([ 3.5595945]), array([ 5.21135257]), array([ 0.70760653]), array([ 3.32916309]), array([ 2.09930594]), array([ 3.14037262]), array([ 2.2110568]), array([ 0.88826585]), array([ 6.5115677]), array([ 4.27384928]), array([ 7.31784495]), array([ 2.77125351]), array([ 2.04122215]), array([ 5.9171162]), array([ 4.35767964]), array([ 6.9480343]), array([ 1.68248784]), array([ 4.90395589]), array([ 1.17067567]), array([ 7.85670228]), array([ 1.70363096]), array([ 9.50582384]), array([ 6.96359572]), array([ 6.56027762]), array([ 4.03951186]), array([ 2.53647197]), array([ 2.68494019]), array([ 7.65414744]), array([ 2.47866698]), array([ 6.87096047]), array([ 1.39624018]), array([-0.12358222]), array([ 2.76300824]), array([ 6.47062023]), array([ 6.3994277]), array([ 1.03808144]), array([ 6.69064968]), array([ 5.46153223]), array([ 3.68833052]), array([ 1.4189387]), array([ 4.82888378])]

# %%
x_vals = np.asarray([[i] for i in random_x])
val_noise = np.asarray(val_noise)
normal_again = inv(x_vals.T.dot(x_vals)).dot(x_vals.T).dot(val_noise) 
plt.plot(x_vals, x_vals.dot(normal_again), 'r--')

# %% [markdown]
# Let y be a function be $ y = f(x) + \epsilon$

# %%
a = np.random.random([100]) * 4

# %%
plt.figure()
points = np.matrix('0; 2; 3; 4')
plt.scatter(np.matrix('0; 2; 3; 4'), y)
plt.plot([0,2,3,4], X.dot(theta))
colors = np.random.rand(100)
plt.scatter(random_x, val_noise, c= colors)
plt.plot(x_vals, x_vals.dot(normal_again), 'g--')
plt.savefig('white_noise.png')
